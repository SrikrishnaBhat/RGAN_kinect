# %%
import numpy as np

# %%
ls
# Out:
# axis.json*                             kernel.py*
# data/                                  LICENSE*
# data_utils_copy.py*                    merge_gen_data.py
# data_utils.py*                         mmd.py*
# differential_privacy/                  mod_core_rnn_cell_impl.py*
# eICU_synthetic_dataset_generation.py*  model.py*
# eICU_task.py*                          mountains/
# eICU_tstr_evaluation.py*               plotting.py*
# eugenium_mmd.py*                       __pycache__/
# eval.py*                               tf_ops.py*
# experiment.py*                         tstr.py*
# experiments/                           Untitled.ipynb
# figures/                               utils.py*
# gen_synthetic.py*

# %%
pwd
# Out:
# '/home/srikrishna/Research/RGAN_kinect/RGAN'

# %%
real = np.load('experiments/data/eval_test_real_337.csv.npy')

# %%
sample = np.load('experiments/data/eval_test_sample_337.csv.npy')

# %%
real
# Out:
# array([[[  -29.98550415,   667.89746094,  -552.74304199, ...,
#            250.15736389,   565.9888916 ,  -552.        ],
#         [  -54.9312439 ,   661.40344238,  -590.84777832, ...,
#            231.74494934,   537.29650879,  -544.58752441],
#         [  -79.78491211,   651.34405518,  -608.08532715, ...,
#            208.07481384,   532.79876709,  -543.72497559],
#         ...,
#         [ -255.11273193,   651.04846191,  -789.84106445, ...,
#            -20.66928101,   391.47631836,  -570.65002441],
#         [ -268.41290283,   638.81567383,  -798.77624512, ...,
#            -57.10641479,   357.13195801,  -567.99304199],
#         [ -276.9921875 ,   644.58673096,  -806.32116699, ...,
#            -98.77093506,   304.91000366,  -584.75012207]],
#
#        [[  289.77679443,   713.06359863,  -255.34680176, ...,
#            294.2364502 ,   708.72302246,  -130.62512207],
#         [  273.2749939 ,   697.52844238,  -260.4486084 , ...,
# ...
